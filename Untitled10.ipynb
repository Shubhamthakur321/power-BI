# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_excel(r"C:\Users\SHUBHAM KUMAR\Desktop\iNuorn\Budget.xlsx")

# %%
data=data.dropna()

# %%
New_column=data.iloc[0]

# %%
df=data[1:]

# %%
df.columns=New_column

# %%
df
# Out:
# 2      Category        Subcategory                 ProductName ProductKey  \
# 3   Accessories         Bike Racks         Hitch Rack - 4-Bike        483
# 4   Accessories        Bike Stands      All-Purpose Bike Stand        486
# 5   Accessories  Bottles and Cages       Water Bottle - 30 oz.        477
# 6   Accessories           Cleaners       Bike Wash - Dissolver        484
# 7   Accessories            Fenders       Fender Set - Mountain        485
# 8   Accessories            Helmets       Sport-100 Helmet, Red        212
# 9   Accessories    Hydration Packs     Hydration Pack - 70 oz.        487
# 10  Accessories    Tires and Tubes         Patch Kit/8 Patches        480
# 12        Bikes     Mountain Bikes     Mountain-100 Silver, 38        344
# 13        Bikes         Road Bikes            Road-150 Red, 62        310
# 14        Bikes      Touring Bikes       Touring-2000 Blue, 60        560
# 16     Clothing               Caps                AWC Logo Cap        223
# ...

# %%
fig,ax=plt.subplots(figsize=(12,5))
ax.plot(df.iloc[2,5:])
ax.plot(df.iloc[1,5:])
plt.xlabel("Months")
plt.ylabel("vlaues")

plt.show()

# %%
df.iloc[1:3,5:]
# Out:
# 2 Feb, 2016 Mar, 2016 Apr, 2016 May, 2016 Jun, 2016 Jul, 2016 Aug, 2016  \
# 4      3695      2868      4862      3439      4612      2774      3003
# 5      4727      3656      4449      4051      6257      4871      5231
#
# 2 Sep, 2016 Oct, 2016 Nov, 2016 Dec, 2016 Grand Total
# 4      2401      4413      3881      2143       38757
# 5      5461      5529      5220      6025       57369

# %%
plt.hist(df.iloc[1,5:])
# Out:
# (array([11.,  0.,  0.,  0.,  0.,  0.,  0.,  0.,  0.,  1.]),
#  array([2143.0, 5804.4, 9465.8, 13127.2, 16788.6, 20450.0, 24111.4,
#         27772.8, 31434.2, 35095.6, 38757.0], dtype=object),
#  <BarContainer object of 10 artists>)

# %%
d1=df.iloc[0:8,:]

# %%
d1
# Out:
# 2      Category        Subcategory              ProductName ProductKey  \
# 3   Accessories         Bike Racks      Hitch Rack - 4-Bike        483
# 4   Accessories        Bike Stands   All-Purpose Bike Stand        486
# 5   Accessories  Bottles and Cages    Water Bottle - 30 oz.        477
# 6   Accessories           Cleaners    Bike Wash - Dissolver        484
# 7   Accessories            Fenders    Fender Set - Mountain        485
# 8   Accessories            Helmets    Sport-100 Helmet, Red        212
# 9   Accessories    Hydration Packs  Hydration Pack - 70 oz.        487
# 10  Accessories    Tires and Tubes      Patch Kit/8 Patches        480
#
# 2  Jan, 2016 Feb, 2016 Mar, 2016 Apr, 2016 May, 2016 Jun, 2016 Jul, 2016  \
# 3       1131      2635      4134      2179      2637      3279      2218
# 4        666      3695      2868      4862      3439      4612      2774
# 5       1892      4727      3656      4449      4051      6257      4871
# ...

# %%
sns.catplot(x="Subcategory", y="Grand Total", data=d1,kind="bar", height=6, aspect=15/6)
plt.show()

# %%
d2=df.iloc[8:11,:]

# %%
d2
# Out:
# 2  Category     Subcategory              ProductName ProductKey Jan, 2016  \
# 12    Bikes  Mountain Bikes  Mountain-100 Silver, 38        344    370105
# 13    Bikes      Road Bikes         Road-150 Red, 62        310    346295
# 14    Bikes   Touring Bikes    Touring-2000 Blue, 60        560    133631
#
# 2  Feb, 2016 Mar, 2016 Apr, 2016 May, 2016 Jun, 2016 Jul, 2016 Aug, 2016  \
# 12    326786    384811    439822    458523    619456    524348    647048
# 13    289524    355097    346783    399691    546092    441037    432400
# 14    165941    178287    265901    286630    445270    299106    407069
#
# 2  Sep, 2016 Oct, 2016 Nov, 2016 Dec, 2016 Grand Total
# 12    557368    615032    802831    788234     6534364
# 13    468572    483913    558232    590261     5257897
# 14    391580    481316    506411    494823     4055965

# %%
sns.catplot(x="Subcategory", y="Grand Total", data=d2,kind="bar", height=6, aspect=15/6)
plt.show()

# %%
d3=df.iloc[11:,:]

# %%
d3
# Out:
# 2   Category Subcategory                 ProductName ProductKey Jan, 2016  \
# 16  Clothing        Caps                AWC Logo Cap        223       479
# 17  Clothing      Gloves       Half-Finger Gloves, S        462       598
# 18  Clothing     Jerseys  Long-Sleeve Logo Jersey, S        226      4087
# 19  Clothing      Shorts      Men's Sports Shorts, S        445       421
# 20  Clothing       Socks      Mountain Bike Socks, M        218        24
# 21  Clothing       Vests             Classic Vest, S        471       980
#
# 2  Feb, 2016 Mar, 2016 Apr, 2016 May, 2016 Jun, 2016 Jul, 2016 Aug, 2016  \
# 16      1695      1462      1079      1729      2180      1588      2065
# 17      2474      2957      2705      2819      2966      2975      3264
# 18     11508     12872     11809     12789     18153     16846     13497
# 19      5723      7301      6335      5288      6829      4617      5384
# 20       244       432       547       385       372       839       487
# ...

# %%
sns.catplot(x="Subcategory", y="Grand Total", data=d3,kind="bar", height=6, aspect=15/6)
plt.show()

# %%
sns.catplot(x="Subcategory", y="Jan, 2016", data=d3,kind="bar", height=6, aspect=15/6)
sns.catplot(x="Subcategory", y="Feb, 2016", data=d3,kind="bar", height=6, aspect=15/6)
plt.show()

# %%
fig,ax=plt.subplots(figsize=(12,5))
ax.plot(d1.iloc[:,5:])
plt.xlabel("Months")
plt.ylabel("vlaues")

plt.show()
